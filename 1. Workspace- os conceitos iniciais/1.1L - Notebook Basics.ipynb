# %% [markdown]
# ## 01-Lab: Get started with Databricks Notebook

# %% [markdown]
# #### Q1 - Altere o nome do notebook
#
# Renomeie o notebook atual para "1.-lab-databricks"

# %% [markdown]
# #### Q2 - Attaching um cluster
#
# Faça o attaching do cluster serveless

# %% [markdown]
# %md
# # Title 1
# ## Title 2
# ### Title 3
#
# - Texto com **negrito** e *itálico*
#
# Lista ordenada
# 1. first
# 1. second
# 1. third
#
# Lista não ordenada
# * coffee
# * tea
# * milk
#
#
# - Imagens:
# ![Associate-badge](https://www.databricks.com/wp-content/uploads/2022/04/associate-badge-eng.svg)
#
# E é claro, tabelas:
#
# | user_id | user_name |
# |---------|-----------|
# |    1    |    Adam   |
# |    2    |    Sarah  |
# |    3    |    John   |
#
# - Links (or Embedded HTML): <a href="https://docs.databricks.com/notebooks/notebooks-manage.html" target="_blank"> Crie um notebook na Databricks </a>

# %% [markdown]
# #### Q3 - Execute código python

# %%
x = 5
y = 10
result = x + y
print(result)
# Out:
# 15

# %% [markdown]
# #### Q4 - Célula com markdown
#
# 1. Insira uma acélula de texto abaixo
# 1. Na célula reproduza em markdow a imagem
#
# <div>
#   <img src="https://raw.githubusercontent.com/derar-alhussein/Databricks-Certified-Data-Engineer-Associate/main/Labs/Includes/images/markdown.png">
# </div>

# %% [markdown]
# #### Q5 - Usando comando  %run
#
# ### Exercício
#
# 1. Crie uma nova célula Python chamado **country** no notebook atual.
#
# 2. No célula **country**, declare uma variável chamada **`my_country`** e atribua a ela o nome do seu país. Por exemplo:
#
# ```python
# my_country = "Brasil"
#
# ```

# %%
--------------------

# %%
print(my_country)
